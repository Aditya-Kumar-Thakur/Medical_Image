# %%
import os
import librosa

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

import librosa.display

import plotly.express as px
import IPython.display as ipd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

from tqdm import tqdm, trange
from librosa import feature, amplitude_to_db, load

from tqdm.auto import tqdm
from plotly.subplots import make_subplots

from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , Activation , Dropout

pd.plotting.register_matplotlib_converters()

# %matplotlib inline

# %%
import librosa
import numpy as np
import pandas as pd
from scipy.fft import fft

# Step 4.1: Extract GFCC (Generalized Frequency Cepstral Coefficients)
def extract_gfcc(audio_file, n_gfcc=13, gamma=1.0):
    """
    Extract GFCC features from an audio file.
    GFCC(x) ← DCT(log(FFT(x))) with a generalized frequency scale.
    """
    y, sr = librosa.load(audio_file, sr=None)

    # Apply FFT
    fft_values = np.abs(fft(y))

    # Compute logarithm of the FFT values
    log_fft_values = np.log1p(fft_values)

    # Apply Generalized Frequency Scale (Gamma)
    freq_scale = np.linspace(0, sr / 2, len(log_fft_values))
    generalized_freq = np.power(freq_scale, gamma)

    # Apply DCT to the log of FFT values (GFCC)
    gfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_gfcc)  # MFCC extraction can be adapted to GFCC
    gfccs = np.dot(np.diag(generalized_freq), gfccs)  # Applying frequency scale adjustment

    return gfccs.T  # Transpose to get frame-wise GFCCs

# Step 4.2: Extract Prosody Features (e.g., pitch, energy)
def extract_prosody_features(audio_file):
    """
    Extract prosody features like pitch and energy from an audio file.
    """
    y, sr = librosa.load(audio_file, sr=None)
    
    # Pitch (Fundamental Frequency)
    pitches, magnitudes = librosa.piptrack(y=y, sr=sr)
    pitch = pitches[pitches > 0].mean()  # Mean pitch
    
    # Energy (Root Mean Square Energy)
    rms = librosa.feature.rms(y=y)
    mean_energy = np.mean(rms)
    
    return {"pitch": pitch, "energy": mean_energy}

# Step 4.3: Extract Statistical Features
def extract_statistical_features(features):
    """
    Extract statistical features (mean, standard deviation, min, max) for given features.
    """
    stats = {
        "mean": np.mean(features, axis=0),
        "std_dev": np.std(features, axis=0),
        "min": np.min(features, axis=0),
        "max": np.max(features, axis=0)
    }
    return stats

# Wrapper Function to Process Data
def process_audio_files(audio_files):
    """
    Process multiple audio files to extract GFCC, prosody, and statistical features.
    """
    all_features = []
    
    for file in audio_files:
        print(f"Processing: {file}")
        
        # Extract GFCC Features
        gfcc = extract_gfcc(file)
        gfcc_stats = extract_statistical_features(gfcc)
        
        # Extract Prosody Features
        prosody = extract_prosody_features(file)
        
        # Combine Features
        combined_features = {
            **{f"GFCC_mean_{i+1}": gfcc_stats["mean"][i] for i in range(len(gfcc_stats["mean"]))},
            **{f"GFCC_std_{i+1}": gfcc_stats["std_dev"][i] for i in range(len(gfcc_stats["std_dev"]))},
            **prosody
        }
        
        all_features.append(combined_features)
    
    return pd.DataFrame(all_features)

# Example Usage
audio_files = [
    r"C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav",  # Add paths to your audio files
]

features_df = process_audio_files(audio_files)

# Save to CSV
output_csv = "R1audio_gfcc_features.csv"
features_df.to_csv(output_csv, index=False)
print(f"Features saved to {output_csv}")
# Out:
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 93
#      88 # Example Usage
#      89 audio_files = [
#      90     r"C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav",  # Add paths to your audio files
#      91 ]
# ---> 93 features_df = process_audio_files(audio_files)
#      95 # Save to CSV
#      96 output_csv = "R1audio_gfcc_features.csv"
#
# Cell In[2], line 71, in process_audio_files(audio_files)
#      68 print(f"Processing: {file}")
#      70 # Extract GFCC Features
# ---> 71 gfcc = extract_gfcc(file)
#      72 gfcc_stats = extract_statistical_features(gfcc)
#      74 # Extract Prosody Features
#
# Cell In[2], line 26, in extract_gfcc(audio_file, n_gfcc, gamma)
#      24 # Apply DCT to the log of FFT values (GFCC)
#      25 gfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_gfcc)  # MFCC extraction can be adapted to GFCC
# ---> 26 gfccs = np.dot(np.diag(generalized_freq), gfccs)  # Applying frequency scale adjustment
#      28 return gfccs.T
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\lib\twodim_base.py:293, in diag(v, k)
#     291 if len(s) == 1:
#     292     n = s[0]+abs(k)
# --> 293     res = zeros((n, n), v.dtype)
#     294     if k >= 0:
#     295         i = k
#
# MemoryError: Unable to allocate 43.1 TiB for an array with shape (2433938, 2433938) and data type float64

# %%
import librosa
import numpy as np
import pandas as pd
from scipy.fft import fft

# Step 4.1: Extract GFCC (Generalized Frequency Cepstral Coefficients)
def extract_gfcc(audio_file, n_gfcc=13, gamma=1.0):
    """
    Extract GFCC features from an audio file.
    GFCC(x) ← DCT(log(FFT(x))) with a generalized frequency scale.
    """
    y, sr = librosa.load(audio_file, sr=None)

    # Apply FFT
    fft_values = np.abs(fft(y))

    # Compute logarithm of the FFT values
    log_fft_values = np.log1p(fft_values)

    # Apply Generalized Frequency Scale (Gamma)
    freq_scale = np.linspace(0, sr / 2, len(log_fft_values))
    generalized_freq = np.power(freq_scale, gamma)

    # Apply the frequency scaling element-wise
    scaled_log_fft_values = log_fft_values * generalized_freq

    # Apply DCT to the scaled log FFT values
    gfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_gfcc)  # MFCC extraction can be adapted to GFCC
    gfccs = np.dot(np.diag(generalized_freq[:n_gfcc]), gfccs)  # Scaling for the desired number of GFCCs

    return gfccs.T  # Transpose to get frame-wise GFCCs

# Step 4.2: Extract Prosody Features (e.g., pitch, energy)
def extract_prosody_features(audio_file):
    """
    Extract prosody features like pitch and energy from an audio file.
    """
    y, sr = librosa.load(audio_file, sr=None)
    
    # Pitch (Fundamental Frequency)
    pitches, magnitudes = librosa.piptrack(y=y, sr=sr)
    pitch = pitches[pitches > 0].mean()  # Mean pitch
    
    # Energy (Root Mean Square Energy)
    rms = librosa.feature.rms(y=y)
    mean_energy = np.mean(rms)
    
    return {"pitch": pitch, "energy": mean_energy}

# Step 4.3: Extract Statistical Features
def extract_statistical_features(features):
    """
    Extract statistical features (mean, standard deviation, min, max) for given features.
    """
    stats = {
        "mean": np.mean(features, axis=0),
        "std_dev": np.std(features, axis=0),
        "min": np.min(features, axis=0),
        "max": np.max(features, axis=0)
    }
    return stats

# Wrapper Function to Process Data
def process_audio_files(audio_files):
    """
    Process multiple audio files to extract GFCC, prosody, and statistical features.
    """
    all_features = []
    
    for file in audio_files:
        print(f"Processing: {file}")
        
        # Extract GFCC Features
        gfcc = extract_gfcc(file)
        gfcc_stats = extract_statistical_features(gfcc)
        
        # Extract Prosody Features
        prosody = extract_prosody_features(file)
        
        # Combine Features
        combined_features = {
            **{f"GFCC_mean_{i+1}": gfcc_stats["mean"][i] for i in range(len(gfcc_stats["mean"]))},
            **{f"GFCC_std_{i+1}": gfcc_stats["std_dev"][i] for i in range(len(gfcc_stats["std_dev"]))},
            **prosody
        }
        
        all_features.append(combined_features)
    
    return pd.DataFrame(all_features)

# Example Usage
audio_files = [
    r"C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav",  # Add paths to your audio files
]

features_df = process_audio_files(audio_files)

# Save to CSV
output_csv = "R1audio_gfcc_features.csv"
features_df.to_csv(output_csv, index=False)
print(f"Features saved to {output_csv}")
# Out:
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav
# Features saved to R1audio_gfcc_features.csv

# %%
# Out:
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\001-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\003-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\005-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\005-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\007-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\007-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\010-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\010-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\010-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\010-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\010-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\014-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\016-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\016-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\016-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\016-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\018-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\023-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\023-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\024-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\024-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\029-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\029-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\030-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\030-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\033-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\033-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\033-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\033-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\033-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\035-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\035-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\039-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\043-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\046-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\046-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\049-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\049-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\050-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\051-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\051-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\051-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\051-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\053-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\057-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\057-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\057-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\058-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\058-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\058-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\058-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\061-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\061-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\062-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\065-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\065-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\065-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\066-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\067-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\067-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\070-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\076-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\076-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\076-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\078-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\078-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\087-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\089-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\091-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\091-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\091-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\094-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\094-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\094-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\097-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\120-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\120-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\120-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\120-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\120-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\122-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\122-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\125-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\127-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\134-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\134-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\134-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\134-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\144-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\144-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\148-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\154-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\154-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\157-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\157-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\157-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\164-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\164-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\164-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\168-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\168-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\172-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\172-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\172-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\173-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\178-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\178-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\181-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\181-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\181-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\181-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\183-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\183-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\183-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\183-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\184-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\184-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Dementia\184-2.wav
# Features saved to audio_gfcc_features.csv

# %%
import librosa
import numpy as np
import pandas as pd
import os

# Step 4.1: Extract GFCC (Generalized Frequency Cepstral Coefficients)
def extract_gfcc(audio_file, n_gfcc=13, gamma=1.0):
    """
    Extract GFCC features from an audio file.
    GFCC(x) ← DCT(log(FFT(x))) with a generalized frequency scale.
    """
    y, sr = librosa.load(audio_file, sr=None)

    # Apply FFT
    fft_values = np.abs(np.fft.fft(y))

    # Compute logarithm of the FFT values
    log_fft_values = np.log1p(fft_values)

    # Apply Generalized Frequency Scale (Gamma)
    freq_scale = np.linspace(0, sr / 2, len(log_fft_values))
    generalized_freq = np.power(freq_scale, gamma)

    # Apply the frequency scaling element-wise
    scaled_log_fft_values = log_fft_values * generalized_freq

    # Apply DCT to the scaled log FFT values
    gfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_gfcc)  # MFCC extraction can be adapted to GFCC
    gfccs = np.dot(np.diag(generalized_freq[:n_gfcc]), gfccs)  # Scaling for the desired number of GFCCs

    return gfccs.T  # Transpose to get frame-wise GFCCs

# Step 4.2: Extract Prosody Features (e.g., pitch, energy)
def extract_prosody_features(audio_file):
    """
    Extract prosody features like pitch and energy from an audio file.
    """
    y, sr = librosa.load(audio_file, sr=None)
    
    # Pitch (Fundamental Frequency)
    pitches, magnitudes = librosa.piptrack(y=y, sr=sr)
    pitch = pitches[pitches > 0].mean()  # Mean pitch
    
    # Energy (Root Mean Square Energy)
    rms = librosa.feature.rms(y=y)
    mean_energy = np.mean(rms)
    
    return {"pitch": pitch, "energy": mean_energy}

# Step 4.3: Extract Statistical Features
def extract_statistical_features(features):
    """
    Extract statistical features (mean, standard deviation, min, max) for given features.
    """
    stats = {
        "mean": np.mean(features, axis=0),
        "std_dev": np.std(features, axis=0),
        "min": np.min(features, axis=0),
        "max": np.max(features, axis=0)
    }
    return stats

# Wrapper Function to Process All Audio Files in a Folder
def process_audio_files_in_folder(folder_path):
    """
    Process all audio files in a folder to extract GFCC, prosody, and statistical features.
    """
    all_features = []
    
    # Get all .wav files in the folder
    audio_files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]
    
    for file in audio_files:
        file_path = os.path.join(folder_path, file)
        print(f"Processing: {file_path}")
        
        # Extract GFCC Features
        gfcc = extract_gfcc(file_path)
        gfcc_stats = extract_statistical_features(gfcc)
        
        # Extract Prosody Features
        prosody = extract_prosody_features(file_path)
        
        # Combine Features
        combined_features = {
            **{f"GFCC_mean_{i+1}": gfcc_stats["mean"][i] for i in range(len(gfcc_stats["mean"]))},
            **{f"GFCC_std_{i+1}": gfcc_stats["std_dev"][i] for i in range(len(gfcc_stats["std_dev"]))},
            **prosody
        }
        
        all_features.append(combined_features)
    
    return pd.DataFrame(all_features)

# Example Usage
folder_path = r"C:\Users\adity\OneDrive\Desktop\Speech Sample\Control"  # Update to your folder path
features_df = process_audio_files_in_folder(folder_path)

# Save to CSV
output_csv = "audio_gfcc_features_Control.csv"
features_df.to_csv(output_csv, index=False)
print(f"Features saved to {output_csv}")
# Out:
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\002-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\002-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\002-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\002-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\006-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\006-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\006-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\013-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\013-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\013-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\013-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\015-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\015-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\015-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\015-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\015-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\017-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\021-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\021-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\021-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\021-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\021-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\022-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\022-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\022-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\028-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\028-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\034-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\034-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\034-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\034-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\034-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\042-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\042-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\042-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\042-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\045-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\045-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\045-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\052-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\052-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\054-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\055-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\056-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\056-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\056-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\059-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\059-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\059-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\068-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\068-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\068-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\071-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\071-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\071-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\071-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\071-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\073-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\073-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\073-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\086-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\086-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\086-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\086-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\086-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\092-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\092-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\092-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\092-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\093-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\093-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\096-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\096-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\105-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\105-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\105-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\107-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\107-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\109-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\109-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\109-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\113-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\113-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\113-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\113-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\114-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\114-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\114-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\114-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\114-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\118-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\118-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\118-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\118-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\118-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\121-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\121-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\121-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\121-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\121-4.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\124-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\124-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\128-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\128-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\128-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\129-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\130-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\130-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\130-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\132-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\132-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\137-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\137-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\137-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\137-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\138-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\138-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\139-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\139-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\139-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\140-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\140-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\141-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\141-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\141-2.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\141-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\142-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\142-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\142-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\143-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\145-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\145-3.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\146-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\150-0.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\150-1.wav
# Processing: C:\Users\adity\OneDrive\Desktop\Speech Sample\Control\150-2.wav
# Features saved to audio_gfcc_features_Control.csv

# %%
import pandas as pd

# File paths for the two CSV files
file1_path = r"C:\Users\adity\audio_gfcc_features.csv"  # Replace with your first file path
file2_path = r"C:\Users\adity\audio_gfcc_features_Control.csv"  # Replace with your second file path

# Load the CSV files into DataFrames
df1 = pd.read_csv(file1_path)
df2 = pd.read_csv(file2_path)

# Add a new column to each DataFrame
df1['Output'] = 1  # Mark rows from the first file as 1
df2['Output'] = 0  # Mark rows from the second file as 0

# Combine the two DataFrames
combined_df = pd.concat([df1, df2], ignore_index=True)

# Save the combined DataFrame to a new CSV file
output_file_path = 'Combined_GFCC.csv'  # Replace with your desired output file path
combined_df.to_csv(output_file_path, index=False)

print("Files combined successfully!")
# Out:
# Files combined successfully!
